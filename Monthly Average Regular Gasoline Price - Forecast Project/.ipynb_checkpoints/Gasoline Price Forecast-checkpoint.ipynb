# %% [markdown]
# # Regular Gasoline Price Forecast - Time Series

# %% [markdown]
# ## Data Set Info:
# This [data set](https://catalog.data.gov/dataset/short-term-energy-outlook-real-and-nominal-petroleum-prices) was scraped from the Department of Energy, which provides annual, quarterly, and monthly prices back to 1976 for gasoline , heating oil, and diesel fuel. Also provides annual prices from 1968 and quarterly and monthly prices from 1974 for imported crude oil. Based on Form EIA-878 data.

# %% [markdown]
# ### Goal:
# Forecast the monthly average real price of regular Gasoline ($/gallon) in the United States.

# %% [markdown]
# ### Data Attributes
#
# - Month: the time periods are periodically seperated per month from 1976 to February 2023
# - CPI(1982-84 =1): Consumer Price Index is a measure of the average change over time in the prices paid by urban consumers for a market basket of consumer goods and services.
# - Nominal: The price paid for a product or service at the time of the transaction.
# - Motor Gasoline Price($/gallon): The relative or real price is its value in terms of some other good, service, or bundle of goods

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# setting our seaborn color palette
color_pal = sns.color_palette() 
plt.style.use('fivethirtyeight')

# %%
# Load the data
gas = pd.read_csv('gasoline.csv')
# dataframe shape
gas.shape
# Out:
# (566, 4)

# %%
# first 5 observations
gas.head()
# Out:
#            Month  CPI(1982-84 =1)  Nominal  Motor Gasoline Price($/gallon)
# 0   January 1976            0.558     0.61                            3.28
# 1  February 1976            0.559     0.60                            3.24
# 2     March 1976            0.560     0.59                            3.21
# 3     April 1976            0.561     0.59                            3.19
# 4       May 1976            0.564     0.60                            3.22

# %% [markdown]
# Definition: The nominal price of a good is its value in terms of money, such as dollars, French francs, or yen. The relative or real price is its value in terms of some other good, service, or bundle of goods. The term “relative price” is used to make comparisons of different goods at the same moment of time. The term “real price” tends to be used to make comparisons of one good to a group or bundle of other goods across different time periods, such as one year to the next.

# %%
# create a dataframe copy to work with
df = gas.copy()

# %%
# dataframe columns
df.columns
# Out:
# Index(['Month', 'CPI(1982-84 =1)', 'Nominal',
#        'Motor Gasoline Price($/gallon)'],
#       dtype='object')

# %%
# rename the columns of the dataframe
df.rename(columns = {'Month':'Datetime',
                     'Motor Gasoline Price($/gallon)':'Gas Price',
                     'CPI(1982-84 =1)':'CPI'},
          inplace = True)

# %%
# check column names
df.columns
# Out:
# Index(['Datetime', 'CPI', 'Nominal', 'Gas Price'], dtype='object')

# %%
# first 5 rows
df.head()
# Out:
#         Datetime    CPI  Nominal  Gas Price
# 0   January 1976  0.558     0.61       3.28
# 1  February 1976  0.559     0.60       3.24
# 2     March 1976  0.560     0.59       3.21
# 3     April 1976  0.561     0.59       3.19
# 4       May 1976  0.564     0.60       3.22

# %%
# Set the Datetime as our index
df = df.set_index('Datetime')
df.head()
# Out:
#                  CPI  Nominal  Gas Price
# Datetime
# January 1976   0.558     0.61       3.28
# February 1976  0.559     0.60       3.24
# March 1976     0.560     0.59       3.21
# April 1976     0.561     0.59       3.19
# May 1976       0.564     0.60       3.22

# %%
# check the data type of our index
df.index
# Out:
# Index(['January 1976', 'February 1976', 'March 1976', 'April 1976', 'May 1976',
#        'June 1976', 'July 1976', 'August 1976', 'September 1976',
#        'October 1976',
#        ...
#        'May 2022', 'June 2022', 'July 2022', 'August 2022', 'September 2022',
#        'October 2022', 'November 2022', 'December 2022', 'January 2023',
#        'February 2023'],
#       dtype='object', name='Datetime', length=566)

# %%
# make the index from object to datetime data type
# makes our plot look cleaner
df.index = pd.to_datetime(df.index)

# %%
# check the index 
df.head()
# Out:
#               CPI  Nominal  Gas Price
# Datetime
# 1976-01-01  0.558     0.61       3.28
# 1976-02-01  0.559     0.60       3.24
# 1976-03-01  0.560     0.59       3.21
# 1976-04-01  0.561     0.59       3.19
# 1976-05-01  0.564     0.60       3.22

# %%
# print the last 5 rows
df.tail()
# Out:
#               CPI  Nominal  Gas Price
# Datetime
# 2022-10-01  2.980     3.82       3.87
# 2022-11-01  2.986     3.69       3.73
# 2022-12-01  2.990     3.21       3.24
# 2023-01-01  3.005     3.34       3.36
# 2023-02-01  3.018     3.39       3.39

# %%
# plot the Gasoline Price
df['Gas Price'].plot(figsize = (15,7))
plt.title("Monthly Average Regular Gasoline Price")
plt.ylabel("Gasoline Price per Gallon $")
plt.xlabel("Year")
plt.show()

# %%
# Plot the Nominal Gas Price
df['Nominal'].plot(figsize = (15,7), 
                   color = color_pal[1])
plt.title("Monthly Average Nominal Gasoline Price")
plt.ylabel("Nominal Gasoline Price per Gallon $")
plt.xlabel("Year")
plt.show()

# %%
# Plot the Gasoline Real Price alongside its nominal price
fig, ax = plt.subplots(figsize = (15,8))
fig = df['Gas Price'].plot(color = 'b', title = "Monthly Average Regular Gasoline Price")
df['Nominal'].plot(figsize = (15,7), color = color_pal[1], ax = ax)
plt.ylabel("Gasoline Price per Gallon $")
plt.xlabel("Year")
plt.legend(['Real', 'Nominal'])
plt.show()

# %%
# index max or last date in our dataframe
df.index.max()
# Out:
# Timestamp('2023-02-01 00:00:00')

# %%
# index min or first date in our dataframe
df.index.min()
# Out:
# Timestamp('1976-01-01 00:00:00')

# %%
# plot the last 8 years of data
plt.figure(figsize = (12,6))
df.loc[(df.index > '2015-01-01') & (df.index <= '2023-02-01')].plot()
plt.title('Gasoline Prices in the Last 8 years')
plt.ylabel("Gasoline Price per Gallon $")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# ## Train Test Split

# %%
# training data everything before January 1, 2018
train = df.loc[df.index < '01-01-2018']

# testing data everything after January 1, 2018
test = df.loc[df.index >= '01-01-2018']

# %%
# dataset shapes
train.shape, test.shape
# Out:
# ((504, 3), (62, 3))

# %%
# plot the training and testing data
fig, ax = plt.subplots(figsize = (15,6))
fig = train['Gas Price'].plot(ax = ax, 
                        label = 'Training Set',  
                        title = 'Data Train/Test Split', 
                        color = color_pal[0])

test['Gas Price'].plot(ax = ax, 
                       label = 'Testing Set', 
                       color = color_pal[2])

ax.legend(['Training Set', 'Testing Set'])
plt.show()

# %%
# plot last 2 years of data
df.loc[(df.index > '01-01-2020') & (df.index < '02-01-2023')].plot()
plt.title("Gas Prices from 2020 to Early 2023")
plt.show()

# %% [markdown]
# ## Time Series Cross Validation

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
tss = TimeSeriesSplit(n_splits = 5, test_size = 12*1*3, gap = 0)
df = df.sort_index()

# %%
# get indices
fig, axs = plt.subplots(5, 1, figsize = (15,15), sharex = True)
fold = 0 
for train_idx, val_idx in tss.split(df):
    
    train = df.iloc[train_idx]
    test = df.iloc[val_idx]
    train['Gas Price'].plot(ax = axs[fold], 
                          label = 'Training Set',
                          title = f'Data Train/Test Split Fold {fold}')
    test['Gas Price'].plot(ax = axs[fold], 
                         label = 'Testing Set')
    axs[fold].axvline(test.index.min(), color = 'black', ls = '--')
                          
    fold += 1

# %% [markdown]
# ## Feature Engineering

# %%
# feature engineering function for time series index

def create_features(df):
    """ 
    create time series features based on time series index
    """ 
    df = df.copy()
    # start from monday as 0 and sunday as a 6
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] =  df.index.dayofyear
    return df

#df = create_features(df)

# %%
df.tail(24)
# Out:
#               CPI  Nominal  Gas Price
# Datetime
# 2021-03-01  2.649     2.81       3.21
# 2021-04-01  2.667     2.86       3.24
# 2021-05-01  2.684     2.99       3.36
# 2021-06-01  2.706     3.06       3.42
# 2021-07-01  2.718     3.14       3.49
# 2021-08-01  2.729     3.16       3.50
# 2021-09-01  2.740     3.18       3.50
# 2021-10-01  2.765     3.29       3.60
# 2021-11-01  2.787     3.39       3.68
# 2021-12-01  2.809     3.31       3.56
# 2022-01-01  2.826     3.31       3.54
# 2022-02-01  2.846     3.52       3.74
# 2022-03-01  2.875     4.22       4.44
# 2022-04-01  2.886     4.11       4.30
# 2022-05-01  2.913     4.44       4.61
# 2022-06-01  2.947     4.93       5.05
# 2022-07-01  2.946     4.56       4.68
# 2022-08-01  2.953     3.98       4.07
# 2022-09-01  2.965     3.70       3.77
# 2022-10-01  2.980     3.82       3.87
# 2022-11-01  2.986     3.69       3.73
# 2022-12-01  2.990     3.21       3.24
# 2023-01-01  3.005     3.34       3.36
# 2023-02-01  3.018     3.39       3.39

# %%
# add lagging indicators for future predicitions

def add_lags(df):
    #target_map = df['Gas Price'].to_dict()
    df = df.copy()
    df['lag1'] = df['Gas Price'].shift(1)
    df['lag2'] = df['Gas Price'].shift(2)
    df['lag3'] = df['Gas Price'].shift(3)
    df['lag4'] = df['Gas Price'].shift(4)
    df['lag5'] = df['Gas Price'].shift(5)
    df['lag6'] = df['Gas Price'].shift(6)
    df['lag7'] = df['Gas Price'].shift(8)
    df['lag8'] = df['Gas Price'].shift(10)
    df['lag9'] = df['Gas Price'].shift(11)
    df['lag10'] = df['Gas Price'].shift(13)
    df['lag11'] = df['Gas Price'].shift(15)
    df['lag12'] = df['Gas Price'].shift(16)
    return df


df = add_lags(df)

# %%
df.tail()
# Out:
#               CPI  Nominal  Gas Price  lag1  lag2  lag3  lag4  lag5  lag6  \
# Datetime
# 2022-10-01  2.980     3.82       3.87  3.77  4.07  4.68  5.05  4.61  4.30
# 2022-11-01  2.986     3.69       3.73  3.87  3.77  4.07  4.68  5.05  4.61
# 2022-12-01  2.990     3.21       3.24  3.73  3.87  3.77  4.07  4.68  5.05
# 2023-01-01  3.005     3.34       3.36  3.24  3.73  3.87  3.77  4.07  4.68
# 2023-02-01  3.018     3.39       3.39  3.36  3.24  3.73  3.87  3.77  4.07
#
#             lag7  lag8  lag9  lag10  lag11  lag12
# Datetime
# 2022-10-01  3.74  3.56  3.68   3.50   3.49   3.42
# 2022-11-01  4.44  3.54  3.56   3.60   3.50   3.49
# 2022-12-01  4.30  3.74  3.54   3.68   3.50   3.50
# 2023-01-01  4.61  4.44  3.74   3.56   3.60   3.50
# 2023-02-01  5.05  4.30  4.44   3.54   3.68   3.60

# %% [markdown]
# ## XGBoost Model

# %%
# import XGBoost
import xgboost as xgb

# %%
# train = create_features(train)
# test = create_features(test)

# %%
# add lagging indicators for train and testing sets
train = add_lags(train)
test = add_lags(test)

# %%
# check the test index
test.index
# Out:
# DatetimeIndex(['2020-03-01', '2020-04-01', '2020-05-01', '2020-06-01',
#                '2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01',
#                '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01',
#                '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01',
#                '2021-07-01', '2021-08-01', '2021-09-01', '2021-10-01',
#                '2021-11-01', '2021-12-01', '2022-01-01', '2022-02-01',
#                '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01',
#                '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
#                '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01'],
#               dtype='datetime64[ns]', name='Datetime', freq=None)

# %%
# choosing our variables
df.columns
# Out:
# Index(['CPI', 'Nominal', 'Gas Price', 'lag1', 'lag2', 'lag3', 'lag4', 'lag5',
#        'lag6', 'lag7', 'lag8', 'lag9', 'lag10', 'lag11', 'lag12'],
#       dtype='object')

# %%
# Our Predictors 
Features = ['CPI', 'Nominal','lag1', 'lag2', 'lag3', 
            'lag4', 'lag5','lag6','lag7', 'lag8', 
            'lag9', 'lag10', 'lag11', 'lag12']

# Our Response Variable
Target = 'Gas Price'

# %%
# train test split
X_train = train[Features]
y_train = train[Target]

X_test = test[Features]
y_test = test[Target]

# %%
##### n estimators number of trees
# instantiate our model 
boost = xgb.XGBRegressor(n_estimators = 2500, early_stopping_rounds = 50, learning_rate = 0.01)
boost.fit(X_train, y_train, 
        eval_set = [(X_train, y_train), (X_test, y_test)],
        verbose = 100)
# Out:
# [0]	validation_0-rmse:2.75698	validation_1-rmse:2.90812
# [100]	validation_0-rmse:1.03459	validation_1-rmse:1.07945
# [200]	validation_0-rmse:0.40185	validation_1-rmse:0.43397
# [300]	validation_0-rmse:0.16859	validation_1-rmse:0.28430
# [400]	validation_0-rmse:0.08202	validation_1-rmse:0.27283
# [462]	validation_0-rmse:0.05872	validation_1-rmse:0.27644
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=2500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# ## Feature Importance

# %%
# training set columns
X_train.columns
# Out:
# Index(['CPI', 'Nominal', 'lag1', 'lag2', 'lag3', 'lag4', 'lag5', 'lag6',
#        'lag7', 'lag8', 'lag9', 'lag10', 'lag11', 'lag12'],
#       dtype='object')

# %%
# printing the column importance in our model
boost.feature_importances_
# Out:
# array([0.00201639, 0.01162798, 0.93143386, 0.00262586, 0.00155758,
#        0.00127322, 0.00236617, 0.00247564, 0.02838011, 0.00329648,
#        0.00600041, 0.001853  , 0.00236327, 0.00273001], dtype=float32)

# %%
# placing our column importance in a dataframe
fi = pd.DataFrame(data = boost.feature_importances_, 
                  index = boost.feature_names_in_,
                  columns = ['importance'])

# %%
# plot which features were importance in the model as a bundle
fi.sort_values('importance').plot( kind = 'barh', 
                                  title = 'Feature Importance')
plt.show()

# %% [markdown]
# ## Forecast on Test

# %%
# get test predicitions
test['prediction'] = boost.predict(X_test)

# %%
# combining the original dataframe with test predictions
df = df.merge(test[['prediction']], 
              how = 'left', 
              left_index = True, 
              right_index = True)

# %%
# check predictions
df.tail()
# Out:
#               CPI  Nominal  Gas Price  lag1  lag2  lag3  lag4  lag5  lag6  \
# Datetime
# 2022-10-01  2.980     3.82       3.87  3.77  4.07  4.68  5.05  4.61  4.30
# 2022-11-01  2.986     3.69       3.73  3.87  3.77  4.07  4.68  5.05  4.61
# 2022-12-01  2.990     3.21       3.24  3.73  3.87  3.77  4.07  4.68  5.05
# 2023-01-01  3.005     3.34       3.36  3.24  3.73  3.87  3.77  4.07  4.68
# 2023-02-01  3.018     3.39       3.39  3.36  3.24  3.73  3.87  3.77  4.07
#
#             lag7  lag8  lag9  lag10  lag11  lag12  prediction
# Datetime
# 2022-10-01  3.74  3.56  3.68   3.50   3.49   3.42    4.195356
# 2022-11-01  4.44  3.54  3.56   3.60   3.50   3.49    4.185282
# 2022-12-01  4.30  3.74  3.54   3.68   3.50   3.50    3.658448
# 2023-01-01  4.61  4.44  3.74   3.56   3.60   3.50    2.879720
# 2023-02-01  5.05  4.30  4.44   3.54   3.68   3.60    3.361447

# %%
# plot the predicitions vs actual values
ax = df[['Gas Price']].plot(figsize = (15,6))
df['prediction'].plot(ax = ax, 
                      style = '.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Data and Predictions')
plt.show()

# %%
# plot the last 6 years of data along side the predictions
ax = df.loc[df.index >= '01-01-2018']['Gas Price'] \
.plot(figsize = (15,6), 
      title = 'Test Set')
df.loc[df.index >= '01-01-2018']['prediction'] \
.plot(style = '.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Data and Predictions')
plt.show()

# %%
# Root mean squared error for our predictions and actual prices
rmse = mean_squared_error(test['Gas Price'],
                          test['prediction'], 
                          squared = False)
print(f'RMSE score on Test set is: {rmse:0.4f}')
# Out:
# RMSE score on Test set is: 0.2719

# %% [markdown]
# ## Training Using Cross Validation

# %%
# 5-fold Cross Validation for Time Series
tss = TimeSeriesSplit(n_splits = 5, test_size = 12*1*3, gap = 0)
df = df.sort_index()


fold = 0
preds = []
scores = []

for train_idx, val_idx in tss.split(df):
    
    train = df.iloc[train_idx]
    test = df.iloc[val_idx]

    #train = create_features(train)
    #test = create_features(test)
    # add lagging indicators for train and testing sets
    train = add_lags(train)
    test = add_lags(test)
    
    # Our Predictors 
    Features = ['CPI', 'Nominal','lag1', 'lag2', 'lag3', 'lag4', 'lag5'
                ,'lag6','lag7', 'lag8', 'lag9', 'lag10', 'lag11', 'lag12']

    # Our Response Variable
    Target = 'Gas Price'

    X_train = train[Features]
    y_train = train[Target]

    X_test = test[Features]
    y_test = test[Target]

    reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                           n_estimators=1500,
                           early_stopping_rounds=50,
                           objective='reg:squarederror',
                           max_depth=3,
                           learning_rate=0.01)
    reg.fit(X_train, y_train,
            eval_set=[(X_train, y_train), (X_test, y_test)],
            verbose=100)

    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = mean_squared_error(y_test, y_pred, squared = False)
    scores.append(score)
# Out:
# [0]	validation_0-rmse:2.51599	validation_1-rmse:3.45936
# [100]	validation_0-rmse:0.94521	validation_1-rmse:1.46123
# [200]	validation_0-rmse:0.36749	validation_1-rmse:0.76664
# [300]	validation_0-rmse:0.16111	validation_1-rmse:0.57730
# [400]	validation_0-rmse:0.09471	validation_1-rmse:0.53081
# [500]	validation_0-rmse:0.07376	validation_1-rmse:0.51145
# [600]	validation_0-rmse:0.06500	validation_1-rmse:0.50919
# [676]	validation_0-rmse:0.06131	validation_1-rmse:0.50895
# [0]	validation_0-rmse:2.60967	validation_1-rmse:4.15463
# [100]	validation_0-rmse:0.98372	validation_1-rmse:1.76396
# [200]	validation_0-rmse:0.38605	validation_1-rmse:0.72506
# [300]	validation_0-rmse:0.17193	validation_1-rmse:0.45710
# [400]	validation_0-rmse:0.10226	validation_1-rmse:0.42780
# [426]	validation_0-rmse:0.09441	validation_1-rmse:0.43066
# [0]	validation_0-rmse:2.76213	validation_1-rmse:2.84829
# [100]	validation_0-rmse:1.03774	validation_1-rmse:1.13532
# [200]	validation_0-rmse:0.40380	validation_1-rmse:0.53763
# [300]	validation_0-rmse:0.17859	validation_1-rmse:0.40645
# [400]	validation_0-rmse:0.10585	validation_1-rmse:0.37722
# [500]	validation_0-rmse:0.08403	validation_1-rmse:0.36538
# [600]	validation_0-rmse:0.07584	validation_1-rmse:0.36076
# [700]	validation_0-rmse:0.07145	validation_1-rmse:0.35950
# [800]	validation_0-rmse:0.06777	validation_1-rmse:0.35811
# [900]	validation_0-rmse:0.06427	validation_1-rmse:0.35838
# [902]	validation_0-rmse:0.06423	validation_1-rmse:0.35838
# [0]	validation_0-rmse:2.76850	validation_1-rmse:2.59315
# [100]	validation_0-rmse:1.03979	validation_1-rmse:0.95438
# [200]	validation_0-rmse:0.40592	validation_1-rmse:0.36272
# [300]	validation_0-rmse:0.18206	validation_1-rmse:0.18001
# [400]	validation_0-rmse:0.11070	validation_1-rmse:0.14148
# [500]	validation_0-rmse:0.08864	validation_1-rmse:0.13777
# [600]	validation_0-rmse:0.07999	validation_1-rmse:0.13672
# [690]	validation_0-rmse:0.07643	validation_1-rmse:0.13614
# [0]	validation_0-rmse:2.75698	validation_1-rmse:2.90812
# [100]	validation_0-rmse:1.03478	validation_1-rmse:1.08054
# [200]	validation_0-rmse:0.40379	validation_1-rmse:0.41991
# [300]	validation_0-rmse:0.18190	validation_1-rmse:0.26149
# [400]	validation_0-rmse:0.11202	validation_1-rmse:0.24270
# [440]	validation_0-rmse:0.10092	validation_1-rmse:0.24752

# %%
# Cross Validation results
print(f'RMSE mean score across 5-folds: {np.mean(scores):0.4f}')
print(f'5-Fold scores: {scores}')
# Out:
# RMSE mean score across 5-folds: 0.3343
# 5-Fold scores: [0.5085725181333824, 0.4261613409981201, 0.3579647614935152, 0.13609696516370537, 0.24258769595246604]

# %% [markdown]
# ## Predicting the Future with XGBoost Regressor

# %%
# get all columns
df.columns
# Out:
# Index(['CPI', 'Nominal', 'Gas Price', 'lag1', 'lag2', 'lag3', 'lag4', 'lag5',
#        'lag6', 'lag7', 'lag8', 'lag9', 'lag10', 'lag11', 'lag12',
#        'prediction'],
#       dtype='object')

# %%
# Retrain on all data 
df = add_lags(df)

# Our Predictors 
Features = ['CPI', 'Nominal','lag1', 'lag2', 'lag3', 'lag4', 
            'lag5','lag6','lag7', 'lag8', 'lag9', 'lag10', 
            'lag11', 'lag12']

# Our Response Variable
Target = 'Gas Price'

X_all = df[Features]
y_all = df[Target]

reg = xgb.XGBRegressor(n_estimators = 500, 
                       base_score = 0.5,
                       booster = 'gbtree',
                       objective = 'reg:squarederror',
                       max_depth = 3,
                       learning_rate = 0.01)

reg.fit(X_all, y_all, 
        eval_set = [(X_all,y_all)],
        verbose = 100)
# Out:
# [0]	validation_0-rmse:2.76681
# [100]	validation_0-rmse:1.03844
# [200]	validation_0-rmse:0.40688
# [300]	validation_0-rmse:0.18590
# [400]	validation_0-rmse:0.11667
# [499]	validation_0-rmse:0.09596
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# Create future dataframe with future dates.

# %%
# get the max date in our dataframe
df.index.max()
# Out:
# Timestamp('2023-02-01 00:00:00')

# %%
# check the values of our last date
df.tail(1)
# Out:
#               CPI  Nominal  Gas Price  lag1  lag2  lag3  lag4  lag5  lag6  \
# Datetime
# 2023-02-01  3.018     3.39       3.39  3.36  3.24  3.73  3.87  3.77  4.07
#
#             lag7  lag8  lag9  lag10  lag11  lag12  prediction
# Datetime
# 2023-02-01  5.05   4.3  4.44   3.54   3.68    3.6    3.361447

# %%
# create a future dataframe
# where the dates are seperated by the start of the month 
future = pd.date_range('2023-03-01', 
                       '2024-05-01', 
                       freq = 'MS')
future
# Out:
# DatetimeIndex(['2023-03-01', '2023-04-01', '2023-05-01', '2023-06-01',
#                '2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01', '2024-05-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
# make a future dates into a dataframe
future_df = pd.DataFrame(index = future)
# if the dates are in the future set to True
future_df['isFuture'] = True
# if the dates are not in the future set to false
df['isFuture'] = False
# combine the orginal dataframe with future dates
df_and_future = pd.concat([df,future_df])

# %%
# check combined dataframe
df_and_future.tail(10)
# Out:
#             CPI  Nominal  Gas Price  lag1  lag2  lag3  lag4  lag5  lag6  lag7  \
# 2023-08-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-09-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-10-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-11-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-12-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-01-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-02-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-03-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-04-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-05-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#             lag8  lag9  lag10  lag11  lag12  prediction  isFuture
# 2023-08-01   NaN   NaN    NaN    NaN    NaN         NaN      True
# 2023-09-01   NaN   NaN    NaN    NaN    NaN         NaN      True
# 2023-10-01   NaN   NaN    NaN    NaN    NaN         NaN      True
# 2023-11-01   NaN   NaN    NaN    NaN    NaN         NaN      True
# 2023-12-01   NaN   NaN    NaN    NaN    NaN         NaN      True
# 2024-01-01   NaN   NaN    NaN    NaN    NaN         NaN      True
# 2024-02-01   NaN   NaN    NaN    NaN    NaN         NaN      True
# 2024-03-01   NaN   NaN    NaN    NaN    NaN         NaN      True
# 2024-04-01   NaN   NaN    NaN    NaN    NaN         NaN      True
# 2024-05-01   NaN   NaN    NaN    NaN    NaN         NaN      True

# %%
# add the lags to the combined datasets
df_and_future = add_lags(df_and_future)

# %%
# return the dataframe with future dates
future_w_features = df_and_future.query('isFuture').copy()

# %%
# print the remaining dataframe
future_w_features
# Out:
#             CPI  Nominal  Gas Price  lag1  lag2  lag3  lag4  lag5  lag6  lag7  \
# 2023-03-01  NaN      NaN        NaN  3.39  3.36  3.24  3.73  3.87  3.77  4.68
# 2023-04-01  NaN      NaN        NaN   NaN  3.39  3.36  3.24  3.73  3.87  4.07
# 2023-05-01  NaN      NaN        NaN   NaN   NaN  3.39  3.36  3.24  3.73  3.77
# 2023-06-01  NaN      NaN        NaN   NaN   NaN   NaN  3.39  3.36  3.24  3.87
# 2023-07-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN  3.39  3.36  3.73
# 2023-08-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN  3.39  3.24
# 2023-09-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN  3.36
# 2023-10-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN  3.39
# 2023-11-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-12-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-01-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-02-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-03-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-04-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-05-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#             lag8  lag9  lag10  lag11  lag12  prediction  isFuture
# 2023-03-01  4.61  4.30   3.74   3.56   3.68         NaN      True
# 2023-04-01  5.05  4.61   4.44   3.54   3.56         NaN      True
# 2023-05-01  4.68  5.05   4.30   3.74   3.54         NaN      True
# 2023-06-01  4.07  4.68   4.61   4.44   3.74         NaN      True
# 2023-07-01  3.77  4.07   5.05   4.30   4.44         NaN      True
# 2023-08-01  3.87  3.77   4.68   4.61   4.30         NaN      True
# 2023-09-01  3.73  3.87   4.07   5.05   4.61         NaN      True
# 2023-10-01  3.24  3.73   3.77   4.68   5.05         NaN      True
# 2023-11-01  3.36  3.24   3.87   4.07   4.68         NaN      True
# 2023-12-01  3.39  3.36   3.73   3.77   4.07         NaN      True
# 2024-01-01   NaN  3.39   3.24   3.87   3.77         NaN      True
# 2024-02-01   NaN   NaN   3.36   3.73   3.87         NaN      True
# 2024-03-01   NaN   NaN   3.39   3.24   3.73         NaN      True
# 2024-04-01   NaN   NaN    NaN   3.36   3.24         NaN      True
# 2024-05-01   NaN   NaN    NaN   3.39   3.36         NaN      True

# %%
# predict the gas price on the future dates
future_w_features['pred'] = reg.predict(future_w_features[Features])

# %%
# check the predicitons
future_w_features
# Out:
#             CPI  Nominal  Gas Price  lag1  lag2  lag3  lag4  lag5  lag6  lag7  \
# 2023-03-01  NaN      NaN        NaN  3.39  3.36  3.24  3.73  3.87  3.77  4.68
# 2023-04-01  NaN      NaN        NaN   NaN  3.39  3.36  3.24  3.73  3.87  4.07
# 2023-05-01  NaN      NaN        NaN   NaN   NaN  3.39  3.36  3.24  3.73  3.77
# 2023-06-01  NaN      NaN        NaN   NaN   NaN   NaN  3.39  3.36  3.24  3.87
# 2023-07-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN  3.39  3.36  3.73
# 2023-08-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN  3.39  3.24
# 2023-09-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN  3.36
# 2023-10-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN  3.39
# 2023-11-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-12-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-01-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-02-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-03-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-04-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-05-01  NaN      NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#             lag8  lag9  lag10  lag11  lag12  prediction  isFuture      pred
# 2023-03-01  4.61  4.30   3.74   3.56   3.68         NaN      True  3.408125
# 2023-04-01  5.05  4.61   4.44   3.54   3.56         NaN      True  3.374997
# 2023-05-01  4.68  5.05   4.30   3.74   3.54         NaN      True  3.396175
# 2023-06-01  4.07  4.68   4.61   4.44   3.74         NaN      True  3.347114
# 2023-07-01  3.77  4.07   5.05   4.30   4.44         NaN      True  3.252508
# 2023-08-01  3.87  3.77   4.68   4.61   4.30         NaN      True  3.224850
# 2023-09-01  3.73  3.87   4.07   5.05   4.61         NaN      True  3.177983
# 2023-10-01  3.24  3.73   3.77   4.68   5.05         NaN      True  3.197117
# 2023-11-01  3.36  3.24   3.87   4.07   4.68         NaN      True  3.197117
# 2023-12-01  3.39  3.36   3.73   3.77   4.07         NaN      True  3.247585
# 2024-01-01   NaN  3.39   3.24   3.87   3.77         NaN      True  3.248471
# 2024-02-01   NaN   NaN   3.36   3.73   3.87         NaN      True  3.248471
# 2024-03-01   NaN   NaN   3.39   3.24   3.73         NaN      True  3.247585
# 2024-04-01   NaN   NaN    NaN   3.36   3.24         NaN      True  3.247585
# 2024-05-01   NaN   NaN    NaN   3.39   3.36         NaN      True  3.247585

# %%
# plot the future dates and predicted prices
future_w_features['pred'].plot(figsize=(10, 5),
                               color=color_pal[4],
                               ms=1,
                               lw=2,
                               title='Future Predictions')
plt.show()
